# %% [markdown]
# **Prepare data for Analysis**

# %% [markdown]
# Import relevant libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import datetime

# %% [markdown]
# Access and save file path to a variable

# %%
location = "C:\\Users\\Administrator\\Documents\\capstone_project\\further-analysis\\*xlsx"
excel_files = glob.glob(location)

# %% [markdown]
# Merge excel files to a single dataframe

# %%
trip_data = pd.DataFrame()

for files in excel_files:
    df = pd.read_excel(files)
    trip_data = pd.concat([trip_data, df], ignore_index=True)

# %% [markdown]
# View Dataframe

# %%
trip_data.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  0DA46DD62F111D09  electric_bike 2021-04-01 00:03:18 2021-04-01 00:30:59
# 1  FF009F812ADAFB3E   classic_bike 2021-04-01 00:03:47 2021-04-01 00:23:26
# 2  623C22F8DEC21AE3  electric_bike 2021-04-01 00:04:12 2021-04-01 00:25:44
# 3  8089677A9443153D   classic_bike 2021-04-01 00:04:59 2021-04-01 00:14:29
# 4  B5DF5147C986AF69  electric_bike 2021-04-01 00:08:20 2021-04-01 00:25:52
#
#   member_casual  duration  day_of_week      ride_length
# 0        member  00:27:41            5  0 days, 0:27:41
# 1        member  00:19:39            5  0 days, 0:19:39
# 2        member  00:21:32            5  0 days, 0:21:32
# 3        member  00:09:30            5   0 days, 0:9:30
# 4        member  00:17:32            5  0 days, 0:17:32

# %% [markdown]
# Drop irrelevant columns

# %%
trip_data = trip_data.drop(columns=['duration'])

# %% [markdown]
# Arrange dataframe by start time, i.e from oldest to newest

# %%
trip_data.sort_values(by:= ['started_at'], inplace=True)
trip_data.head()
# Out:
#                   ride_id  rideable_type          started_at  \
# 1417644  A3F8D895163BBB49  electric_bike 2021-01-01 00:02:05
# 1417645  0D139A3203274B87   classic_bike 2021-01-01 00:02:24
# 1417646  C7AE8E9CDB197A8E   classic_bike 2021-01-01 00:06:55
# 1417647  2633EB2B8A99F5CB  electric_bike 2021-01-01 00:12:13
# 1417648  6604F61AE4B14BC1  electric_bike 2021-01-01 00:12:49
#
#                    ended_at member_casual  day_of_week      ride_length
# 1417644 2021-01-01 00:12:39        member            6  0 days, 0:10:34
# 1417645 2021-01-01 00:08:39        member            6   0 days, 0:6:15
# 1417646 2021-01-01 00:26:36        member            6  0 days, 0:19:41
# 1417647 2021-01-01 00:20:06        member            6   0 days, 0:7:53
# 1417648 2021-01-01 00:43:59        member            6  0 days, 0:31:10

# %% [markdown]
# Update index to match dataframe sequence

# %%
trip_data = trip_data.reset_index(drop=True)
trip_data.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  A3F8D895163BBB49  electric_bike 2021-01-01 00:02:05 2021-01-01 00:12:39
# 1  0D139A3203274B87   classic_bike 2021-01-01 00:02:24 2021-01-01 00:08:39
# 2  C7AE8E9CDB197A8E   classic_bike 2021-01-01 00:06:55 2021-01-01 00:26:36
# 3  2633EB2B8A99F5CB  electric_bike 2021-01-01 00:12:13 2021-01-01 00:20:06
# 4  6604F61AE4B14BC1  electric_bike 2021-01-01 00:12:49 2021-01-01 00:43:59
#
#   member_casual  day_of_week      ride_length
# 0        member            6  0 days, 0:10:34
# 1        member            6   0 days, 0:6:15
# 2        member            6  0 days, 0:19:41
# 3        member            6   0 days, 0:7:53
# 4        member            6  0 days, 0:31:10

# %% [markdown]
# Validate data type of each column in Dataframe

# %% [markdown]
# *Examine data types*

# %%
trip_data.dtypes
# Out:
# ride_id                  object
# rideable_type            object
# started_at       datetime64[ns]
# ended_at         datetime64[ns]
# member_casual            object
# day_of_week               int64
# ride_length              object
# dtype: object

# %% [markdown]
# *The column 'ride_length' should be timedelta series for accurate analysis, but is stored as object. To convert 'ride_length' to timedelta type;*
# - *convert object to string*
# - *convert string to timedelta*

# %%
trip_data.ride_length = trip_data.ride_length.astype('string')
trip_data.ride_length = pd.to_timedelta(trip_data.ride_length, unit= 'd', errors= 'coerce')

# %% [markdown]
# *Confirm data type conversion*

# %%
trip_data.dtypes
# Out:
# ride_id                   object
# rideable_type             object
# started_at        datetime64[ns]
# ended_at          datetime64[ns]
# member_casual             object
# day_of_week                int64
# ride_length      timedelta64[ns]
# dtype: object

# %% [markdown]
# Check for duplicates

# %% [markdown]
# *'ride_id' is the unique identifier in Dataframe. Check for duplicates in 'ride_id'*

# %%
duplicate = trip_data[trip_data.duplicated("ride_id", False)]
duplicate
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, member_casual, day_of_week, ride_length]
# Index: []

# %% [markdown]
# Check for missing values in dataframe

# %%
trip_data.isnull().sum()
# Out:
# ride_id          0
# rideable_type    0
# started_at       0
# ended_at         0
# member_casual    0
# day_of_week      0
# ride_length      0
# dtype: int64

# %% [markdown]
# **Analyze Dataset**

# %% [markdown]
# Descriptive Analysis

# %% [markdown]
# *Mean, Median, Maximum and Minimum 'ride_length'*

# %%
trip_data['ride_length'].mean()
# Out:
# Timedelta('0 days 00:22:16.132847292')

# %%
trip_data['ride_length'].median()
# Out:
# Timedelta('0 days 00:12:12')

# %%
trip_data['ride_length'].max()
# Out:
# Timedelta('38 days 20:24:09')

# %%
trip_data['ride_length'].min()
# Out:
# Timedelta('0 days 00:01:00')

# %% [markdown]
# Study the Customers i.e; Casual Riders and Cyclistic Members, represented as Casual and Members respectively

# %% [markdown]
# *Separate members and casual riders in the dataframe, and compare each group*

# %%
casual = trip_data[trip_data['member_casual'] =='casual']
member = trip_data[trip_data['member_casual'] == 'member']
casual
# Out:
#                   ride_id  rideable_type          started_at  \
# 5        800D57DEC9A6D587  electric_bike 2021-01-01 00:13:12
# 11       F9CF9D475BA24E30  electric_bike 2021-01-01 00:28:15
# 14       E0205096C36BAC7B    docked_bike 2021-01-01 00:35:31
# 16       DC41683B55F3110C   classic_bike 2021-01-01 00:35:51
# 18       D02A7BC5E5A1B62E   classic_bike 2021-01-01 00:36:26
# ...                   ...            ...                 ...
# 5509823  63C0721C1E575329  electric_bike 2021-12-31 23:57:53
# 5509825  7B3D0E8AB0842D5E   classic_bike 2021-12-31 23:58:21
# 5509826  B5AEBEF3B5F41C77  electric_bike 2021-12-31 23:58:45
# 5509827  CE1BE016BCE85CCB  electric_bike 2021-12-31 23:59:27
# 5509829  297D1BD291D07BF3  electric_bike 2021-12-31 23:59:48
#
#                    ended_at member_casual  day_of_week     ride_length
# 5       2021-01-01 00:33:26        casual            6 0 days 00:20:14
# 11      2021-01-01 00:34:15        casual            6 0 days 00:06:00
# 14      2021-01-01 01:01:43        casual            6 0 days 00:26:12
# 16      2021-01-01 14:05:57        casual            6 0 days 13:30:06
# 18      2021-01-01 00:58:37        casual            6 0 days 00:22:11
# ...                     ...           ...          ...             ...
# 5509823 2022-01-01 00:03:09        casual            6 0 days 00:05:16
# 5509825 2022-01-01 00:46:56        casual            6 0 days 00:48:35
# 5509826 2022-01-01 00:47:07        casual            6 0 days 00:48:22
# 5509827 2022-01-01 00:32:34        casual            6 0 days 00:33:07
# 5509829 2022-01-01 00:14:42        casual            6 0 days 00:14:54
#
# [2494892 rows x 7 columns]

# %%
member
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        A3F8D895163BBB49  electric_bike 2021-01-01 00:02:05
# 1        0D139A3203274B87   classic_bike 2021-01-01 00:02:24
# 2        C7AE8E9CDB197A8E   classic_bike 2021-01-01 00:06:55
# 3        2633EB2B8A99F5CB  electric_bike 2021-01-01 00:12:13
# 4        6604F61AE4B14BC1  electric_bike 2021-01-01 00:12:49
# ...                   ...            ...                 ...
# 5509817  395C0E813FE9E4F9  electric_bike 2021-12-31 23:53:59
# 5509820  85FA369DB8D9A6A7  electric_bike 2021-12-31 23:56:47
# 5509822  062FDD7B5E7D35AB  electric_bike 2021-12-31 23:57:47
# 5509824  30ED40455D8B7F3E  electric_bike 2021-12-31 23:57:59
# 5509828  B0466FF51982DE4B  electric_bike 2021-12-31 23:59:39
#
#                    ended_at member_casual  day_of_week     ride_length
# 0       2021-01-01 00:12:39        member            6 0 days 00:10:34
# 1       2021-01-01 00:08:39        member            6 0 days 00:06:15
# 2       2021-01-01 00:26:36        member            6 0 days 00:19:41
# 3       2021-01-01 00:20:06        member            6 0 days 00:07:53
# 4       2021-01-01 00:43:59        member            6 0 days 00:31:10
# ...                     ...           ...          ...             ...
# 5509817 2022-01-01 00:14:29        member            6 0 days 00:20:30
# 5509820 2022-01-01 00:07:53        member            6 0 days 00:11:06
# 5509822 2022-01-01 00:24:36        member            6 0 days 00:26:49
# 5509824 2022-01-01 00:08:43        member            6 0 days 00:10:44
# 5509828 2022-01-01 00:21:08        member            6 0 days 00:21:29
#
# [3014938 rows x 7 columns]

# %% [markdown]
# *Calculate total rides taken as 'ride_count'. To idenify each group, use suffix '_m' for members, and '_c' for casual*

# %%
ride_count_m = len(member.index)
#print('ride_count for member suscribers:' + ride_count_m)

# %%
ride_count_c = len(casual.index)
#print('ride_count for casual subscribers:' + ride_count_c)

# %% [markdown]
# *Create a Dataframe for visualization*

# %%
df = {'Users':['Casual', 'Member'], 'total_ride':[ride_count_c, ride_count_m]}
ride_count = pd.DataFrame(df, index=[1,2])
ride_count
# Out:
#     Users  total_ride
# 1  Casual     2494892
# 2  Member     3014938

# %% [markdown]
# *Plot Chart*

# %%
values = [ride_count_c, ride_count_m]
labels = ['Casual', 'Member']
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct, v=val)
    return my_autopct

plt.pie(values, labels = labels, autopct = make_autopct(values))
# Out:
# ([<matplotlib.patches.Wedge at 0x1b3ce2c8070>,
#   <matplotlib.patches.Wedge at 0x1b3ce2c8640>],
#  [Text(0.16248901849015793, 1.0879325893041836, 'Casual'),
#   Text(-0.16248901849015807, -1.0879325893041836, 'Member')],
#  [Text(0.08863037372190431, 0.5934177759841001, '45.28%  (2494892)'),
#   Text(-0.08863037372190438, -0.5934177759841001, '54.72%  (3014938)')])

# %%
sns.set()
plt.bar(x = ride_count['Users'], height= ride_count['total_ride'])
plt.title('Total Ride for 2021')
plt.xlabel('Customer')
plt.ylabel('Ride Count')
plt.show()

# %% [markdown]
# *Calculate total ride length*

# %%
ride_length_m = member['ride_length'].dt.total_seconds().sum()
ride_length_m
# Out:
# 2506786780.0

# %%
ride_length_c = casual['ride_length'].dt.total_seconds().sum()
ride_length_c
# Out:
# 4855078066.0

# %% [markdown]
# *Create a Dataframe for vizualization*

# %%
df1 = {'Users':['Casual', 'Member'], 'total_ride_length':[ride_length_c, ride_length_m]}
ride_length = pd.DataFrame(df1, index=[1, 2])
ride_length
# Out:
#     Users  total_ride_length
# 1  Casual       4.855078e+09
# 2  Member       2.506787e+09

# %% [markdown]
# *Plot Chart*

# %%
plt.bar(x = ride_length['Users'], height=ride_length['total_ride_length'])
plt.title('Duration of Ride for 2021')
plt.xlabel('Customer')
plt.ylabel('Seconds')
plt.show()

# %% [markdown]
# *Examine Total rides and Average 'ride_length' ;*
# - *by month*

# %% [markdown]
# *Use .resample() method to group the data by month, examine the total rides and average ride length for each month*

# %%
total_rides_monthly_m = member.resample('M', on='started_at').count()
total_rides_monthly_m
# Out:
#             ride_id  rideable_type  started_at  ended_at  member_casual  \
# started_at
# 2021-01-31    77573          77573       77573     77573          77573
# 2021-02-28    38685          38685       38685     38685          38685
# 2021-03-31   142375         142375      142375    142375         142375
# 2021-04-30   197477         197477      197477    197477         197477
# 2021-05-31   269897         269897      269897    269897         269897
# 2021-06-30   352676         352676      352676    352676         352676
# 2021-07-31   373833         373833      373833    373833         373833
# 2021-08-31   385426         385426      385426    385426         385426
# 2021-09-30   385959         385959      385959    385959         385959
# 2021-10-31   367460         367460      367460    367460         367460
# 2021-11-30   248699         248699      248699    248699         248699
# 2021-12-31   174878         174878      174878    174878         174878
#
#             day_of_week  ride_length
# started_at
# 2021-01-31        77573        77573
# 2021-02-28        38685        38685
# 2021-03-31       142375       142375
# 2021-04-30       197477       197477
# 2021-05-31       269897       269897
# 2021-06-30       352676       352676
# 2021-07-31       373833       373833
# 2021-08-31       385426       385426
# 2021-09-30       385959       385959
# 2021-10-31       367460       367460
# 2021-11-30       248699       248699
# 2021-12-31       174878       174878

# %% [markdown]
# *For average ride length, convert 'ride_length' data type from datetime to float, to use .resample() method*

# %%
member['ride_length'] = member['ride_length'].dt.total_seconds()
avg_ride_length_monthly_m = member.resample('M', on='started_at').mean()
avg_ride_length_monthly_m
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10604\502564165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member['ride_length'] = member['ride_length'].dt.total_seconds()
#             day_of_week  ride_length
# started_at
# 2021-01-31     4.186573   783.357276
# 2021-02-28     4.328577  1103.365413
# 2021-03-31     3.980221   850.140172
# 2021-04-30     4.085362   895.048709
# 2021-05-31     4.016147   893.618354
# 2021-06-30     4.002444   895.826101
# 2021-07-31     4.281374   868.846536
# 2021-08-31     3.903138   859.400212
# 2021-09-30     4.093445   837.134776
# 2021-10-31     4.179851   763.000566
# 2021-11-30     3.837108   689.923627
# 2021-12-31     4.214447   670.926572

# %% [markdown]
# *Repeat for Casual riders*

# %%
total_rides_monthly_c = casual.resample('M', on='started_at').count()
total_rides_monthly_c
# Out:
#             ride_id  rideable_type  started_at  ended_at  member_casual  \
# started_at
# 2021-01-31    17842          17842       17842     17842          17842
# 2021-02-28     9964           9964        9964      9964           9964
# 2021-03-31    83148          83148       83148     83148          83148
# 2021-04-30   134945         134945      134945    134945         134945
# 2021-05-31   253346         253346      253346    253346         253346
# 2021-06-30   365023         365023      365023    365023         365023
# 2021-07-31   435927         435927      435927    435927         435927
# 2021-08-31   407517         407517      407517    407517         407517
# 2021-09-30   359226         359226      359226    359226         359226
# 2021-10-31   253829         253829      253829    253829         253829
# 2021-11-30   105373         105373      105373    105373         105373
# 2021-12-31    68752          68752       68752     68752          68752
#
#             day_of_week  ride_length
# started_at
# 2021-01-31        17842        17842
# 2021-02-28         9964         9964
# 2021-03-31        83148        83148
# 2021-04-30       134945       134945
# 2021-05-31       253346       253346
# 2021-06-30       365023       365023
# 2021-07-31       435927       435927
# 2021-08-31       407517       407517
# 2021-09-30       359226       359226
# 2021-10-31       253829       253829
# 2021-11-30       105373       105373
# 2021-12-31        68752        68752

# %%
casual['ride_length'] = casual['ride_length'].dt.total_seconds()
avg_ride_length_monthly_c = casual.resample('M', on='started_at').mean()
avg_ride_length_monthly_c
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10604\3633619148.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   casual['ride_length'] = casual['ride_length'].dt.total_seconds()
#             day_of_week  ride_length
# started_at
# 2021-01-31     4.295987  1564.458581
# 2021-02-28     4.804697  3011.595042
# 2021-03-31     4.012532  2313.624200
# 2021-04-30     4.098870  2309.066842
# 2021-05-31     4.022420  2325.838715
# 2021-06-30     4.132767  2261.433323
# 2021-07-31     4.360572  1994.722626
# 2021-08-31     4.021692  1748.719622
# 2021-09-30     4.132880  1690.249283
# 2021-10-31     4.282651  1743.239913
# 2021-11-30     4.008105  1407.694333
# 2021-12-31     4.355044  1429.549249

# %% [markdown]
# *Create a Dataframe for visualization*

# %%
df2 = total_rides_monthly_c.join(total_rides_monthly_m, lsuffix='c', rsuffix='m')
total_monthly_ride = df2[['ride_idc', 'ride_idm']]
total_monthly_ride.columns = ['Casual', 'Member']
total_monthly_ride['Month'] = total_monthly_ride.index.strftime('%b')
total_monthly_ride
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10604\1479181228.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_monthly_ride['Month'] = total_monthly_ride.index.strftime('%b')
#             Casual  Member Month
# started_at
# 2021-01-31   17842   77573   Jan
# 2021-02-28    9964   38685   Feb
# 2021-03-31   83148  142375   Mar
# 2021-04-30  134945  197477   Apr
# 2021-05-31  253346  269897   May
# 2021-06-30  365023  352676   Jun
# 2021-07-31  435927  373833   Jul
# 2021-08-31  407517  385426   Aug
# 2021-09-30  359226  385959   Sep
# 2021-10-31  253829  367460   Oct
# 2021-11-30  105373  248699   Nov
# 2021-12-31   68752  174878   Dec

# %% [markdown]
# *Plot Chart*

# %%
total_monthly_ride.plot(x= 'Month', y= ['Casual', 'Member'], ylabel= 'Number of Rides',  kind= 'bar',title= 'Total Ride per Month')
# Out:
# <AxesSubplot:title={'center':'Total Ride per Month'}, xlabel='Month', ylabel='Number of Rides'>

# %%
df3 = avg_ride_length_monthly_c.join(avg_ride_length_monthly_m, lsuffix='c', rsuffix='m')
avg_monthly_ride_length = df3[['ride_lengthc', 'ride_lengthm']]
avg_monthly_ride_length.columns = ['Casual', 'Member']
avg_monthly_ride_length['Month'] = avg_monthly_ride_length.index.strftime('%b')
avg_monthly_ride_length
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10604\583847650.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_monthly_ride_length['Month'] = avg_monthly_ride_length.index.strftime('%b')
#                  Casual       Member Month
# started_at
# 2021-01-31  1564.458581   783.357276   Jan
# 2021-02-28  3011.595042  1103.365413   Feb
# 2021-03-31  2313.624200   850.140172   Mar
# 2021-04-30  2309.066842   895.048709   Apr
# 2021-05-31  2325.838715   893.618354   May
# 2021-06-30  2261.433323   895.826101   Jun
# 2021-07-31  1994.722626   868.846536   Jul
# 2021-08-31  1748.719622   859.400212   Aug
# 2021-09-30  1690.249283   837.134776   Sep
# 2021-10-31  1743.239913   763.000566   Oct
# 2021-11-30  1407.694333   689.923627   Nov
# 2021-12-31  1429.549249   670.926572   Dec

# %% [markdown]
# *Plot Chart*

# %%
avg_monthly_ride_length.plot(x= 'Month', y= ['Casual', 'Member'], ylabel='Average', title= 'Average Ride Time per Month', kind= 'bar')
# Out:
# <AxesSubplot:title={'center':'Average Ride Time per Month'}, xlabel='Month', ylabel='Average'>

# %% [markdown]
# - *by day*

# %% [markdown]
# *Match each day of the week to the values on 'day_of_week' column*

# %%
days = {1:'Sunday', 2:'Monday', 3:'Tuesday', 4:'Wednesday', 5:'Thursday', 6:'Friday', 7:'Saturday'}
member['weekday'] = member['day_of_week'].map(days)
member
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10604\1052213613.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member['weekday'] = member['day_of_week'].map(days)
#                   ride_id  rideable_type          started_at  \
# 0        A3F8D895163BBB49  electric_bike 2021-01-01 00:02:05
# 1        0D139A3203274B87   classic_bike 2021-01-01 00:02:24
# 2        C7AE8E9CDB197A8E   classic_bike 2021-01-01 00:06:55
# 3        2633EB2B8A99F5CB  electric_bike 2021-01-01 00:12:13
# 4        6604F61AE4B14BC1  electric_bike 2021-01-01 00:12:49
# ...                   ...            ...                 ...
# 5509817  395C0E813FE9E4F9  electric_bike 2021-12-31 23:53:59
# 5509820  85FA369DB8D9A6A7  electric_bike 2021-12-31 23:56:47
# 5509822  062FDD7B5E7D35AB  electric_bike 2021-12-31 23:57:47
# 5509824  30ED40455D8B7F3E  electric_bike 2021-12-31 23:57:59
# 5509828  B0466FF51982DE4B  electric_bike 2021-12-31 23:59:39
#
#                    ended_at member_casual  day_of_week  ride_length weekday
# 0       2021-01-01 00:12:39        member            6        634.0  Friday
# 1       2021-01-01 00:08:39        member            6        375.0  Friday
# 2       2021-01-01 00:26:36        member            6       1181.0  Friday
# 3       2021-01-01 00:20:06        member            6        473.0  Friday
# 4       2021-01-01 00:43:59        member            6       1870.0  Friday
# ...                     ...           ...          ...          ...     ...
# 5509817 2022-01-01 00:14:29        member            6       1230.0  Friday
# 5509820 2022-01-01 00:07:53        member            6        666.0  Friday
# 5509822 2022-01-01 00:24:36        member            6       1609.0  Friday
# 5509824 2022-01-01 00:08:43        member            6        644.0  Friday
# 5509828 2022-01-01 00:21:08        member            6       1289.0  Friday
#
# [3014938 rows x 8 columns]

# %% [markdown]
# *Use .groupby() method to group dataframe by week day*

# %% [markdown]
# *Total ride by day of the week*

# %%
total_rides_daily_m = member.groupby('weekday').count()
total_rides_daily_m
# Out:
#            ride_id  rideable_type  started_at  ended_at  member_casual  \
# weekday
# Friday      438997         438997      438997    438997         438997
# Monday      409354         409354      409354    409354         409354
# Saturday    425175         425175      425175    425175         425175
# Sunday      369218         369218      369218    369218         369218
# Thursday    444440         444440      444440    444440         444440
# Tuesday     458153         458153      458153    458153         458153
# Wednesday   469601         469601      469601    469601         469601
#
#            day_of_week  ride_length
# weekday
# Friday          438997       438997
# Monday          409354       409354
# Saturday        425175       425175
# Sunday          369218       369218
# Thursday        444440       444440
# Tuesday         458153       458153
# Wednesday       469601       469601

# %% [markdown]
# *Average ride_length by day of week*

# %%
avg_ride_length_daily_m = member.groupby('weekday').mean()
avg_ride_length_daily_m
# Out:
#            day_of_week  ride_length
# weekday
# Friday             6.0   812.618765
# Monday             2.0   807.753827
# Saturday           7.0   932.376059
# Sunday             1.0   956.580993
# Thursday           5.0   778.404912
# Tuesday            3.0   779.218495
# Wednesday          4.0   781.145777

# %% [markdown]
# *Repeat for Casual riders*

# %%
days = {1:'Sunday', 2:'Monday', 3:'Tuesday', 4:'Wednesday', 5:'Thursday', 6:'Friday', 7:'Saturday'}
casual['weekday'] = casual['day_of_week'].map(days)
total_rides_daily_c = casual.groupby('weekday').count()
total_rides_daily_c
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10604\214003281.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   casual['weekday'] = casual['day_of_week'].map(days)
#            ride_id  rideable_type  started_at  ended_at  member_casual  \
# weekday
# Friday      359117         359117      359117    359117         359117
# Monday      282545         282545      282545    282545         282545
# Saturday    550484         550484      550484    550484         550484
# Sunday      474534         474534      474534    474534         474534
# Thursday    282311         282311      282311    282311         282311
# Tuesday     270713         270713      270713    270713         270713
# Wednesday   275188         275188      275188    275188         275188
#
#            day_of_week  ride_length
# weekday
# Friday          359117       359117
# Monday          282545       282545
# Saturday        550484       550484
# Sunday          474534       474534
# Thursday        282311       282311
# Tuesday         270713       270713
# Wednesday       275188       275188

# %%
avg_ride_length_daily_c = casual.groupby('weekday').mean()
avg_ride_length_daily_c
# Out:
#            day_of_week  ride_length
# weekday
# Friday             6.0  1845.723252
# Monday             2.0  1938.104514
# Saturday           7.0  2110.441846
# Sunday             1.0  2284.853448
# Thursday           5.0  1683.980366
# Tuesday            3.0  1700.797269
# Wednesday          4.0  1681.783007

# %% [markdown]
# *Create a Dataframe for Visualization*

# %%
df4 = total_rides_daily_c.join(total_rides_daily_m, lsuffix='_c', rsuffix='_m')
total_daily_rides = df4[['ride_id_c', 'ride_id_m']]
total_daily_rides.columns = ['Casual', 'Member']
total_daily_rides= total_daily_rides.reset_index()
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
total_daily_rides['weekday'] = pd.Categorical(total_daily_rides['weekday'], categories=weekdays, ordered=True)
total_daily_rides = total_daily_rides.sort_values('weekday')
total_daily_rides = total_daily_rides.reset_index(drop=True)
total_daily_rides
# Out:
#      weekday  Casual  Member
# 0     Monday  282545  409354
# 1    Tuesday  270713  458153
# 2  Wednesday  275188  469601
# 3   Thursday  282311  444440
# 4     Friday  359117  438997
# 5   Saturday  550484  425175
# 6     Sunday  474534  369218

# %% [markdown]
# *Plot Chart*

# %%
total_daily_rides.plot(x= 'weekday', y= ['Casual', 'Member'], ylabel = 'Number of Rides', title= 'Total Ride per Day', kind='bar')
# Out:
# <AxesSubplot:title={'center':'Total Ride per Day'}, xlabel='weekday', ylabel='Number of Rides'>

# %%
df5 = avg_ride_length_daily_c.join(avg_ride_length_daily_m, lsuffix='_c', rsuffix='_m')
avg_daily_ride_length = df5[['ride_length_c', 'ride_length_m']]
avg_daily_ride_length.columns = ['Casual', 'Member']
avg_daily_ride_length = avg_daily_ride_length.reset_index()
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
avg_daily_ride_length['weekday'] = pd.Categorical(avg_daily_ride_length['weekday'], categories=weekdays, ordered=True)
avg_daily_ride_length = avg_daily_ride_length.sort_values('weekday')
avg_daily_ride_length = avg_daily_ride_length.reset_index(drop=True)
avg_daily_ride_length
# Out:
#      weekday       Casual      Member
# 0     Monday  1938.104514  807.753827
# 1    Tuesday  1700.797269  779.218495
# 2  Wednesday  1681.783007  781.145777
# 3   Thursday  1683.980366  778.404912
# 4     Friday  1845.723252  812.618765
# 5   Saturday  2110.441846  932.376059
# 6     Sunday  2284.853448  956.580993

# %% [markdown]
# *Plot Chart*

# %%
avg_daily_ride_length.plot(x= 'weekday', y=['Casual', 'Member'], ylabel= 'Average', title= 'Average Ride Length per Day', kind='bar')
# Out:
# <AxesSubplot:title={'center':'Average Ride Length per Day'}, xlabel='weekday', ylabel='Average'>

# %% [markdown]
# - *by hour*

# %% [markdown]
# *To group dataframe by hour of the day, round up 'started_at' column to the hour each ride started, and save to a new column 'start_hour'. Use .groupby() method to group dataframe by 'start_hour'. Calculate total rides and average ride_length each hour*

# %% [markdown]
# *Total rides each hour*

# %%
member['start_hour'] = pd.DatetimeIndex(pd.to_datetime(member['started_at']).round('1h')).time 
total_ride_hourly_m = member.groupby('start_hour').count()
total_ride_hourly_m
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10604\1963784163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member['start_hour'] = pd.DatetimeIndex(pd.to_datetime(member['started_at']).round('1h')).time
#             ride_id  rideable_type  started_at  ended_at  member_casual  \
# start_hour
# 00:00:00      40678          40678       40678     40678          40678
# 01:00:00      26019          26019       26019     26019          26019
# 02:00:00      16869          16869       16869     16869          16869
# 03:00:00       8717           8717        8717      8717           8717
# 04:00:00       6769           6769        6769      6769           6769
# 05:00:00      13135          13135       13135     13135          13135
# 06:00:00      51904          51904       51904     51904          51904
# 07:00:00     113650         113650      113650    113650         113650
# 08:00:00     170289         170289      170289    170289         170289
# 09:00:00     150077         150077      150077    150077         150077
# 10:00:00     123428         123428      123428    123428         123428
# 11:00:00     136996         136996      136996    136996         136996
# 12:00:00     170673         170673      170673    170673         170673
# 13:00:00     176814         176814      176814    176814         176814
# 14:00:00     172782         172782      172782    172782         172782
# 15:00:00     181359         181359      181359    181359         181359
# 16:00:00     221906         221906      221906    221906         221906
# 17:00:00     295781         295781      295781    295781         295781
# 18:00:00     296231         296231      296231    296231         296231
# 19:00:00     229179         229179      229179    229179         229179
# 20:00:00     156971         156971      156971    156971         156971
# 21:00:00     109115         109115      109115    109115         109115
# 22:00:00      84004          84004       84004     84004          84004
# 23:00:00      61592          61592       61592     61592          61592
#
#             day_of_week  ride_length  weekday
# start_hour
# 00:00:00          40678        40678    40678
# 01:00:00          26019        26019    26019
# 02:00:00          16869        16869    16869
# 03:00:00           8717         8717     8717
# 04:00:00           6769         6769     6769
# 05:00:00          13135        13135    13135
# 06:00:00          51904        51904    51904
# 07:00:00         113650       113650   113650
# 08:00:00         170289       170289   170289
# 09:00:00         150077       150077   150077
# 10:00:00         123428       123428   123428
# 11:00:00         136996       136996   136996
# 12:00:00         170673       170673   170673
# 13:00:00         176814       176814   176814
# 14:00:00         172782       172782   172782
# 15:00:00         181359       181359   181359
# 16:00:00         221906       221906   221906
# 17:00:00         295781       295781   295781
# 18:00:00         296231       296231   296231
# 19:00:00         229179       229179   229179
# 20:00:00         156971       156971   156971
# 21:00:00         109115       109115   109115
# 22:00:00          84004        84004    84004
# 23:00:00          61592        61592    61592

# %% [markdown]
# *Average 'ride_length' each hour*

# %%
avg_ride_length_hourly_m = member.groupby('start_hour').mean()
avg_ride_length_hourly_m
# Out:
#             day_of_week  ride_length
# start_hour
# 00:00:00       4.454275   842.508358
# 01:00:00       4.035628   858.859756
# 02:00:00       4.139190   939.805501
# 03:00:00       3.778135   977.409315
# 04:00:00       3.957453   896.415128
# 05:00:00       3.916559   844.927522
# 06:00:00       3.998940   725.173031
# 07:00:00       3.992538   736.808297
# 08:00:00       4.018956   749.616763
# 09:00:00       4.090174   743.588031
# 10:00:00       4.163326   800.564321
# 11:00:00       4.142157   838.761986
# 12:00:00       4.091309   821.513374
# 13:00:00       4.091152   825.886349
# 14:00:00       4.088806   852.357138
# 15:00:00       4.079246   860.071538
# 16:00:00       4.025939   863.140240
# 17:00:00       3.988867   859.719607
# 18:00:00       3.986912   870.229129
# 19:00:00       4.025255   852.423778
# 20:00:00       4.060215   845.549127
# 21:00:00       4.109582   833.385639
# 22:00:00       4.232989   829.557438
# 23:00:00       4.531627   851.965255

# %% [markdown]
# *Repeat for Casual riders*

# %%
casual['start_hour'] = pd.DatetimeIndex(pd.to_datetime(casual['started_at']).round('1h')).time 
total_ride_hourly_c = casual.groupby('start_hour').count()
total_ride_hourly_c
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10604\3401638357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   casual['start_hour'] = pd.DatetimeIndex(pd.to_datetime(casual['started_at']).round('1h')).time
#             ride_id  rideable_type  started_at  ended_at  member_casual  \
# start_hour
# 00:00:00      62343          62343       62343     62343          62343
# 01:00:00      44848          44848       44848     44848          44848
# 02:00:00      32796          32796       32796     32796          32796
# 03:00:00      18242          18242       18242     18242          18242
# 04:00:00      11146          11146       11146     11146          11146
# 05:00:00       9659           9659        9659      9659           9659
# 06:00:00      17202          17202       17202     17202          17202
# 07:00:00      34443          34443       34443     34443          34443
# 08:00:00      56522          56522       56522     56522          56522
# 09:00:00      67700          67700       67700     67700          67700
# 10:00:00      88421          88421       88421     88421          88421
# 11:00:00     117946         117946      117946    117946         117946
# 12:00:00     150858         150858      150858    150858         150858
# 13:00:00     165531         165531      165531    165531         165531
# 14:00:00     173982         173982      173982    173982         173982
# 15:00:00     180731         180731      180731    180731         180731
# 16:00:00     193348         193348      193348    193348         193348
# 17:00:00     221040         221040      221040    221040         221040
# 18:00:00     226267         226267      226267    226267         226267
# 19:00:00     189821         189821      189821    189821         189821
# 20:00:00     139253         139253      139253    139253         139253
# 21:00:00     109056         109056      109056    109056         109056
# 22:00:00      98942          98942       98942     98942          98942
# 23:00:00      84795          84795       84795     84795          84795
#
#             day_of_week  ride_length  weekday
# start_hour
# 00:00:00          62343        62343    62343
# 01:00:00          44848        44848    44848
# 02:00:00          32796        32796    32796
# 03:00:00          18242        18242    18242
# 04:00:00          11146        11146    11146
# 05:00:00           9659         9659     9659
# 06:00:00          17202        17202    17202
# 07:00:00          34443        34443    34443
# 08:00:00          56522        56522    56522
# 09:00:00          67700        67700    67700
# 10:00:00          88421        88421    88421
# 11:00:00         117946       117946   117946
# 12:00:00         150858       150858   150858
# 13:00:00         165531       165531   165531
# 14:00:00         173982       173982   173982
# 15:00:00         180731       180731   180731
# 16:00:00         193348       193348   193348
# 17:00:00         221040       221040   221040
# 18:00:00         226267       226267   226267
# 19:00:00         189821       189821   189821
# 20:00:00         139253       139253   139253
# 21:00:00         109056       109056   109056
# 22:00:00          98942        98942    98942
# 23:00:00          84795        84795    84795

# %%
avg_ride_length_hourly_c = casual.groupby('start_hour').mean()
avg_ride_length_hourly_c
# Out:
#             day_of_week  ride_length
# start_hour
# 00:00:00       4.419855  2142.595993
# 01:00:00       3.870540  2091.992486
# 02:00:00       4.015856  2500.435693
# 03:00:00       3.596535  2797.687644
# 04:00:00       3.777140  2635.811771
# 05:00:00       3.663009  2145.464230
# 06:00:00       3.977270  1374.558947
# 07:00:00       4.007055  1327.763784
# 08:00:00       4.042267  1308.825325
# 09:00:00       4.106573  1557.247105
# 10:00:00       4.119157  1916.896348
# 11:00:00       4.134172  2059.232691
# 12:00:00       4.105516  2070.516360
# 13:00:00       4.140662  2033.582543
# 14:00:00       4.138221  2118.010806
# 15:00:00       4.111541  2067.138499
# 16:00:00       4.100435  1998.966278
# 17:00:00       4.116404  1833.864454
# 18:00:00       4.137612  1799.447807
# 19:00:00       4.209339  1889.555402
# 20:00:00       4.209453  1884.297947
# 21:00:00       4.271448  1935.628310
# 22:00:00       4.367751  1950.359322
# 23:00:00       4.641512  1983.310962

# %% [markdown]
# *Create a Dataframe for Visualization*

# %%
df6 = total_ride_hourly_c.join(total_ride_hourly_m, lsuffix='_c', rsuffix='_m')
total_ride_hourly = df6[['ride_id_c', 'ride_id_m']]
total_ride_hourly.columns = ['Casual', 'Member']
total_ride_hourly = total_ride_hourly.reset_index()
total_ride_hourly
# Out:
#    start_hour  Casual  Member
# 0    00:00:00   62343   40678
# 1    01:00:00   44848   26019
# 2    02:00:00   32796   16869
# 3    03:00:00   18242    8717
# 4    04:00:00   11146    6769
# 5    05:00:00    9659   13135
# 6    06:00:00   17202   51904
# 7    07:00:00   34443  113650
# 8    08:00:00   56522  170289
# 9    09:00:00   67700  150077
# 10   10:00:00   88421  123428
# 11   11:00:00  117946  136996
# 12   12:00:00  150858  170673
# 13   13:00:00  165531  176814
# 14   14:00:00  173982  172782
# 15   15:00:00  180731  181359
# 16   16:00:00  193348  221906
# 17   17:00:00  221040  295781
# 18   18:00:00  226267  296231
# 19   19:00:00  189821  229179
# 20   20:00:00  139253  156971
# 21   21:00:00  109056  109115
# 22   22:00:00   98942   84004
# 23   23:00:00   84795   61592

# %% [markdown]
# *Plot Chart*

# %%
total_ride_hourly.plot(x='start_hour', y=['Casual', 'Member'], ylabel = 'Number of Rides', title= 'Total Ride per Hour', kind='bar')
# Out:
# <AxesSubplot:title={'center':'Total Ride per Hour'}, xlabel='start_hour', ylabel='Number of Rides'>

# %%
df7 = avg_ride_length_hourly_c.join(avg_ride_length_hourly_m, lsuffix='_c', rsuffix='_m')
avg_hourly_ride_length = df7[['ride_length_c', 'ride_length_m']]
avg_hourly_ride_length.columns = ['Casual', 'Member']
avg_hourly_ride_length = avg_hourly_ride_length.reset_index()
avg_hourly_ride_length
# Out:
#    start_hour       Casual      Member
# 0    00:00:00  2142.595993  842.508358
# 1    01:00:00  2091.992486  858.859756
# 2    02:00:00  2500.435693  939.805501
# 3    03:00:00  2797.687644  977.409315
# 4    04:00:00  2635.811771  896.415128
# 5    05:00:00  2145.464230  844.927522
# 6    06:00:00  1374.558947  725.173031
# 7    07:00:00  1327.763784  736.808297
# 8    08:00:00  1308.825325  749.616763
# 9    09:00:00  1557.247105  743.588031
# 10   10:00:00  1916.896348  800.564321
# 11   11:00:00  2059.232691  838.761986
# 12   12:00:00  2070.516360  821.513374
# 13   13:00:00  2033.582543  825.886349
# 14   14:00:00  2118.010806  852.357138
# 15   15:00:00  2067.138499  860.071538
# 16   16:00:00  1998.966278  863.140240
# 17   17:00:00  1833.864454  859.719607
# 18   18:00:00  1799.447807  870.229129
# 19   19:00:00  1889.555402  852.423778
# 20   20:00:00  1884.297947  845.549127
# 21   21:00:00  1935.628310  833.385639
# 22   22:00:00  1950.359322  829.557438
# 23   23:00:00  1983.310962  851.965255

# %% [markdown]
# *Plot Chart*

# %%
avg_hourly_ride_length.plot(x= 'start_hour', y= ['Casual', 'Member'], ylabel= 'Average', title= 'Average Ride Length per Hour',kind='bar')
# Out:
# <AxesSubplot:title={'center':'Average Ride Length per Hour'}, xlabel='start_hour', ylabel='Average'>

# %% [markdown]
# *Examine 'rideable_type'*

# %% [markdown]
# *Use .groupby() method to group rides by 'rideable_type'*

# %%
preferred_ride_m = member.groupby('rideable_type').count()
preferred_ride_m
# Out:
#                ride_id  started_at  ended_at  member_casual  day_of_week  \
# rideable_type
# classic_bike   1955673     1955673   1955673        1955673      1955673
# docked_bike          1           1         1              1            1
# electric_bike  1059264     1059264   1059264        1059264      1059264
#
#                ride_length  weekday  start_hour
# rideable_type
# classic_bike       1955673  1955673     1955673
# docked_bike              1        1           1
# electric_bike      1059264  1059264     1059264

# %% [markdown]
# *Repeat for Casual riders*

# %%
preferred_ride_c = casual.groupby('rideable_type').count()
preferred_ride_c
# Out:
#                ride_id  started_at  ended_at  member_casual  day_of_week  \
# rideable_type
# classic_bike   1253395     1253395   1253395        1253395      1253395
# docked_bike     310390      310390    310390         310390       310390
# electric_bike   931107      931107    931107         931107       931107
#
#                ride_length  weekday  start_hour
# rideable_type
# classic_bike       1253395  1253395     1253395
# docked_bike         310390   310390      310390
# electric_bike       931107   931107      931107

# %% [markdown]
# *Create a Dataframe for Visualization*

# %%
df8 = preferred_ride_c.join(preferred_ride_m, lsuffix='_c', rsuffix='_m')
preferred_ride = df8[['ride_id_c', 'ride_id_m']]
preferred_ride.columns = ['Casual', 'Member']
preferred_ride = preferred_ride.reset_index()
preferred_ride
# Out:
#    rideable_type   Casual   Member
# 0   classic_bike  1253395  1955673
# 1    docked_bike   310390        1
# 2  electric_bike   931107  1059264

# %% [markdown]
# *Plot Chart*

# %%
preferred_ride.plot(x= 'rideable_type', y= ['Casual', 'Member'], ylabel= 'Number of Rides', title= 'Preferred Ride', kind= 'bar')
# Out:
# <AxesSubplot:title={'center':'Preferred Ride'}, xlabel='rideable_type', ylabel='Number of Rides'>
